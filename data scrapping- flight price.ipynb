# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver= webdriver.Chrome(r"E:\chromedriver_win32\chromedriver.exe")

# %%
#Details scrapped
airline=[]
departure_time=[]
departure_city=[]
reaching_time=[]
destination_city=[]
price=[]
journey_time=[]
no_of_stops=[]
date_of_journey=[]

# %%
#Specify Search URL #hyderabad 
url='https://www.kayak.co.in/flights/DEL-HYD/2022-04-19?sort=bestflight_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
try:
    for i in airlines:
        airline.append(i.text)
except:
    airline.append(nan)
print('Length of airlines:',len(airline))
# Out:
# Length of airlines: 64

# %%
#departure time
departure = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
try:
    for dept in departure:
        departure_time.append(dept.text)
except:
    departure_time.append(nan)
print('Length of departure time:',len(departure_time))
# Out:
# Length of departure time: 64

# %%
#departure city
city_from = driver.find_elements_by_xpath('//span[@class="airport-name"]')
try:
    for i in city_from:
        departure_city.append(i.text)
except:
    city_from.append(nan)
print('Length of departure city:',len(departure_city))
# Out:
# Length of departure city: 128

# %%
city_dep= departure_city[0::2]

# %%
#destination city
dest_city = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city:
    destination_city.append(i.text)
print('Length of destination city:',len(destination_city))
# Out:
# Length of destination city: 128

# %%
city_des=destination_city[1::2]

# %%
#Destination arrival time
reach_time=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time:
    reaching_time.append(i.text)
print('Length of reaching time:',len(reaching_time))
# Out:
# Length of reaching time: 64

# %%
#journey_time
journey = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey:
    journey_time.append(i.text)
print('Length of journey time:',len(journey_time))
# Out:
# Length of journey time: 192

# %%
journey_t=journey_time[2: :3]

# %%
#no_of_stops
no_stops= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops:
    no_of_stops.append(i.text)
print('Length of number of stops:',len(no_of_stops))
# Out:
# Length of number of stops: 64

# %%
 #Ticket fare
ticket_price= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price:
    price.append(prices.text)
print('Length of price:',len(price))
# Out:
# Length of price: 690

# %%
import re 
from re import search
pr=[]
for i in price: 
      if search("₹", i):
            pr.append(i)

# %%
fare=pr[0:64]

# %%
from itertools import repeat
given_value ='direct'
stop=[]
stop.extend(repeat(given_value,16))

# %%
flights_hyd_best =pd.DataFrame({})
flights_hyd_best['airline']=airline
flights_hyd_best['departure_city']=city_dep
flights_hyd_best['departure_time']=departure_time
flights_hyd_best['reaching_time']=reaching_time
flights_hyd_best['destination_city']=city_des
flights_hyd_best['journey_time']=journey_t
flights_hyd_best['stop']=no_of_stops
flights_hyd_best['ticket fare']=fare
flights_hyd_best
# Out:
#       airline          departure_city departure_time reaching_time  \
# 0   Air India  DEL Indira Gandhi Intl          09:45         11:50
# 1   Air India  DEL Indira Gandhi Intl          09:45         11:50
# 2    SpiceJet  DEL Indira Gandhi Intl          21:55         00:15
# 3   Air India  DEL Indira Gandhi Intl          07:10         09:25
# 4     Vistara  DEL Indira Gandhi Intl          17:40         19:50
# ..        ...                     ...            ...           ...
# 59    Vistara  DEL Indira Gandhi Intl          07:05         09:25
# 60    Vistara  DEL Indira Gandhi Intl          20:35         22:55
# 61  Air India  DEL Indira Gandhi Intl          17:15         19:30
# 62     IndiGo  DEL Indira Gandhi Intl          07:55         10:15
# 63     IndiGo  DEL Indira Gandhi Intl          06:40         09:00
#
#          destination_city journey_time    stop ticket fare
# 0   HYD Rajiv Gandhi Intl       2h 05m  direct     ₹ 4,510
# ...

# %%
#Specify Search URL #hyderabad 
url='https://www.kayak.co.in/flights/DEL-HYD/2022-04-19?sort=price_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
try:
    for i in airlines:
        airline.append(i.text)
except:
    airline.append(nan)
print('Length of airlines:',len(airline))
# Out:
# Length of airlines: 79

# %%
#departure time
departure = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
try:
    for dept in departure:
        departure_time.append(dept.text)
except:
    departure_time.append(nan)
print('Length of departure time:',len(departure_time))
# Out:
# Length of departure time: 79

# %%
#departure city
city_from = driver.find_elements_by_xpath('//span[@class="airport-name"]')
try:
    for i in city_from:
        departure_city.append(i.text)
except:
    city_from.append(nan)
print('Length of departure city:',len(departure_city))
# Out:
# Length of departure city: 158

# %%
city_dep= departure_city[0::2]

# %%
#destination city
dest_city = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city:
    destination_city.append(i.text)
print('Length of destination city:',len(destination_city))
# Out:
# Length of destination city: 158

# %%
city_des=destination_city[1::2]

# %%
#Destination arrival time
reach_time=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time:
    reaching_time.append(i.text)
print('Length of reaching time:',len(reaching_time))
# Out:
# Length of reaching time: 79

# %%
#journey_time
journey = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey:
    journey_time.append(i.text)
print('Length of journey time:',len(journey_time))
# Out:
# Length of journey time: 237

# %%
journey_t=journey_time[2: :3]

# %%
#no_of_stops
no_stops= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops:
    no_of_stops.append(i.text)
print('Length of number of stops:',len(no_of_stops))
# Out:
# Length of number of stops: 79

# %%
 #Ticket fare
ticket_price= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price:
    price.append(prices.text)
print('Length of price:',len(price))
# Out:
# Length of price: 848

# %%
import re 
from re import search
pr=[]
for i in price: 
      if search("₹", i):
            pr.append(i)

# %%
fare=pr[0:79]

# %%
flights_hyd_cheap =pd.DataFrame({})
flights_hyd_cheap['airline']=airline
flights_hyd_cheap['departure_city']=city_dep
flights_hyd_cheap['departure_time']=departure_time
flights_hyd_cheap['reaching_time']=reaching_time
flights_hyd_cheap['destination_city']=city_des
flights_hyd_cheap['journey_time']=journey_t
flights_hyd_cheap['stop']=no_of_stops
flights_hyd_cheap['ticket fare']=fare
flights_hyd_cheap
# Out:
#       airline          departure_city departure_time reaching_time  \
# 0   Air India  DEL Indira Gandhi Intl          09:45         11:50
# 1   Air India  DEL Indira Gandhi Intl          09:45         11:50
# 2    SpiceJet  DEL Indira Gandhi Intl          21:55         00:15
# 3   Air India  DEL Indira Gandhi Intl          07:10         09:25
# 4     Vistara  DEL Indira Gandhi Intl          17:40         19:50
# ..        ...                     ...            ...           ...
# 74     IndiGo  DEL Indira Gandhi Intl          19:30         21:40
# 75     IndiGo  DEL Indira Gandhi Intl          18:00         20:10
# 76     IndiGo  DEL Indira Gandhi Intl          07:55         10:15
# 77     IndiGo  DEL Indira Gandhi Intl          06:40         09:00
# 78     IndiGo  DEL Indira Gandhi Intl          13:35         18:10
#
#          destination_city journey_time    stop ticket fare
# 0   HYD Rajiv Gandhi Intl       2h 05m  direct     ₹ 4,510
# ...

# %%
#Specify Search URL #hyderabad 
url='https://www.kayak.co.in/flights/DEL-HYD/2022-04-19?sort=duration_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
try:
    for i in airlines:
        airline.append(i.text)
except:
    airline.append(nan)
print('Length of airlines:',len(airline))
# Out:
# Length of airlines: 94

# %%
#departure time
departure = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
try:
    for dept in departure:
        departure_time.append(dept.text)
except:
    departure_time.append(nan)
print('Length of departure time:',len(departure_time))
# Out:
# Length of departure time: 94

# %%
#departure city
city_from = driver.find_elements_by_xpath('//span[@class="airport-name"]')
try:
    for i in city_from:
        departure_city.append(i.text)
except:
    city_from.append(nan)
print('Length of departure city:',len(departure_city))
# Out:
# Length of departure city: 188

# %%
city_dep= departure_city[0::2]

# %%
#destination city
dest_city = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city:
    destination_city.append(i.text)
print('Length of destination city:',len(destination_city))
# Out:
# Length of destination city: 188

# %%
city_des=destination_city[1::2]

# %%
#Destination arrival time
reach_time=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time:
    reaching_time.append(i.text)
print('Length of reaching time:',len(reaching_time))
# Out:
# Length of reaching time: 94

# %%
#journey_time
journey = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey:
    journey_time.append(i.text)
print('Length of journey time:',len(journey_time))
# Out:
# Length of journey time: 282

# %%
journey_t=journey_time[2: :3]

# %%
#no_of_stops
no_stops= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops:
    no_of_stops.append(i.text)
print('Length of number of stops:',len(no_of_stops))
# Out:
# Length of number of stops: 94

# %%
 #Ticket fare
ticket_price= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price:
    price.append(prices.text)
print('Length of price:',len(price))
# Out:
# Length of price: 1010

# %%
import re 
from re import search
pr=[]
for i in price: 
      if search("₹", i):
            pr.append(i)

# %%
fare=pr[0:94]

# %%
flights_hyd =pd.DataFrame({})
flights_hyd['airline']=airline
flights_hyd['departure_city']=city_dep
flights_hyd['departure_time']=departure_time
flights_hyd['reaching_time']=reaching_time
flights_hyd['destination_city']=city_des
flights_hyd['journey_time']=journey_t
flights_hyd['stop']=no_of_stops
flights_hyd['ticket fare']=fare
flights_hyd
# Out:
#       airline          departure_city departure_time reaching_time  \
# 0   Air India  DEL Indira Gandhi Intl          09:45         11:50
# 1   Air India  DEL Indira Gandhi Intl          09:45         11:50
# 2    SpiceJet  DEL Indira Gandhi Intl          21:55         00:15
# 3   Air India  DEL Indira Gandhi Intl          07:10         09:25
# 4     Vistara  DEL Indira Gandhi Intl          17:40         19:50
# ..        ...                     ...            ...           ...
# 89     IndiGo  DEL Indira Gandhi Intl          21:15         23:25
# 90     IndiGo  DEL Indira Gandhi Intl          09:55         12:05
# 91  Air India  DEL Indira Gandhi Intl          21:30         23:45
# 92  Air India  DEL Indira Gandhi Intl          07:10         09:25
# 93    GoFirst  DEL Indira Gandhi Intl          20:55         23:10
#
#          destination_city journey_time    stop ticket fare
# 0   HYD Rajiv Gandhi Intl       2h 05m  direct     ₹ 4,510
# ...

# %%
flights_hyd.to_csv('airlines_hyderabad.csv')

# %%
df1 = pd.read_csv ("airlines_hyderabad.csv")
df1
# Out:
#     Unnamed: 0    airline          departure_city departure_time  \
# 0            0  Air India  DEL Indira Gandhi Intl          09:45
# 1            1  Air India  DEL Indira Gandhi Intl          09:45
# 2            2   SpiceJet  DEL Indira Gandhi Intl          21:55
# 3            3  Air India  DEL Indira Gandhi Intl          07:10
# 4            4    Vistara  DEL Indira Gandhi Intl          17:40
# ..         ...        ...                     ...            ...
# 89          89     IndiGo  DEL Indira Gandhi Intl          21:15
# 90          90     IndiGo  DEL Indira Gandhi Intl          09:55
# 91          91  Air India  DEL Indira Gandhi Intl          21:30
# 92          92  Air India  DEL Indira Gandhi Intl          07:10
# 93          93    GoFirst  DEL Indira Gandhi Intl          20:55
#
#    reaching_time       destination_city journey_time    stop ticket fare
# 0          11:50  HYD Rajiv Gandhi Intl       2h 05m  direct     ₹ 4,510
# ...

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver= webdriver.Chrome(r"E:\chromedriver_win32\chromedriver.exe")

# %%
#Details scrapped
airline_0=[]
departure_time_0=[]
departure_city_0=[]
reaching_time_0=[]
destination_city_0=[]
price_0=[]
journey_time_0=[]
no_of_stops_0=[]
date_of_journey_0=[]

# %%
#Specify Search URL #mumbai 
url='https://www.kayak.co.in/flights/DEL-BOM/2022-04-19?sort=bestflight_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines_0=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
try:
    for i in airlines_0:
        airline_0.append(i.text)
except:
    airline_0.append(nan)
print('Length of airlines:',len(airline_0))

#departure time
departure_0 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
try:
    for dept in departure_0:
        departure_time_0.append(dept.text)
except:
    departure_time_0.append(nan)
print('Length of departure time:',len(departure_time_0))

#departure city
city_from_0 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
try:
    for i in city_from_0:
        departure_city_0.append(i.text)
except:
    city_from_0.append(nan)
print('Length of departure city:',len(departure_city_0))

city_dep_0= departure_city_0[0::2]

#destination city
dest_city_0 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city_0:
    destination_city_0.append(i.text)
print('Length of destination city:',len(destination_city_0))

city_des_0=destination_city_0[1::2]

#Destination arrival time
reach_time_0=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time_0:
    reaching_time_0.append(i.text)
print('Length of reaching time:',len(reaching_time_0))

#journey_time
journey_0 = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey_0:
    journey_time_0.append(i.text)
print('Length of journey time:',len(journey_time_0))

journey_t_0=journey_time_0[2: :3]

#no_of_stops
no_stops_0= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops_0:
    no_of_stops_0.append(i.text)
print('Length of number of stops:',len(no_of_stops_0))
# Out:
# Length of airlines: 16
# Length of departure time: 16
# Length of departure city: 32
# Length of destination city: 32
# Length of reaching time: 16
# Length of journey time: 48
# Length of number of stops: 16

# %%
 #Ticket fare
ticket_price_0= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price_0:
    price_0.append(prices.text)
print('Length of price:',len(price_0))


from re import search
pr_0=[]
for i in price_0: 
      if search("₹", i):
            pr_0.append(i)
            
fare_0=pr_0[0:16]
# Out:
# Length of price: 180

# %%
flights_mum_best =pd.DataFrame({})
flights_mum_best['airline']=airline_0
flights_mum_best['departure_city']=city_dep_0
flights_mum_best['departure_time']=departure_time_0
flights_mum_best['reaching_time']=reaching_time_0
flights_mum_best['destination_city']=city_des_0
flights_mum_best['journey_time']=journey_t_0
flights_mum_best['stop']=no_of_stops_0
flights_mum_best['ticket fare']=fare_0
flights_mum_best
# Out:
#           airline          departure_city departure_time reaching_time  \
# 0         Vistara  DEL Indira Gandhi Intl          06:00         08:00
# 1   AirAsia India  DEL Indira Gandhi Intl          13:00         14:50
# 2       Air India  DEL Indira Gandhi Intl          07:00         09:05
# 3       Air India  DEL Indira Gandhi Intl          20:00         22:10
# 4       Air India  DEL Indira Gandhi Intl          08:00         10:10
# 5         Vistara  DEL Indira Gandhi Intl          06:00         08:00
# 6         Vistara  DEL Indira Gandhi Intl          09:30         11:35
# 7         Vistara  DEL Indira Gandhi Intl          19:50         22:00
# 8         Vistara  DEL Indira Gandhi Intl          20:40         22:50
# 9       Air India  DEL Indira Gandhi Intl          09:00         11:15
# 10        GoFirst  DEL Indira Gandhi Intl          19:50         22:00
# 11        GoFirst  DEL Indira Gandhi Intl          07:00         09:10
# ...

# %%
#Specify Search URL #mumbai 
url='https://www.kayak.co.in/flights/DEL-BOM/2022-04-19?sort=price_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines_0=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
try:
    for i in airlines_0:
        airline_0.append(i.text)
except:
    airline_0.append(nan)
print('Length of airlines:',len(airline_0))

#departure time
departure_0 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
try:
    for dept in departure_0:
        departure_time_0.append(dept.text)
except:
    departure_time_0.append(nan)
print('Length of departure time:',len(departure_time_0))

#departure city
city_from_0 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
try:
    for i in city_from_0:
        departure_city_0.append(i.text)
except:
    city_from_0.append(nan)
print('Length of departure city:',len(departure_city_0))

city_dep_0= departure_city_0[0::2]

#destination city
dest_city_0 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city_0:
    destination_city_0.append(i.text)
print('Length of destination city:',len(destination_city_0))

city_des_0=destination_city_0[1::2]

#Destination arrival time
reach_time_0=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time_0:
    reaching_time_0.append(i.text)
print('Length of reaching time:',len(reaching_time_0))

#journey_time
journey_0 = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey_0:
    journey_time_0.append(i.text)
print('Length of journey time:',len(journey_time_0))

journey_t_0=journey_time_0[2: :3]

#no_of_stops
no_stops_0= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops_0:
    no_of_stops_0.append(i.text)
print('Length of number of stops:',len(no_of_stops_0))
# Out:
# Length of airlines: 31
# Length of departure time: 31
# Length of departure city: 62
# Length of destination city: 62
# Length of reaching time: 31
# Length of journey time: 93
# Length of number of stops: 31

# %%
 #Ticket fare
ticket_price_0= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price_0:
    price_0.append(prices.text)
print('Length of price:',len(price_0))


from re import search
pr_0=[]
for i in price_0: 
      if search("₹", i):
            pr_0.append(i)
            
fare_0=pr_0[0:31]
# Out:
# Length of price: 330

# %%
flights_mum_cheap =pd.DataFrame({})
flights_mum_cheap['airline']=airline_0
flights_mum_cheap['departure_city']=city_dep_0
flights_mum_cheap['departure_time']=departure_time_0
flights_mum_cheap['reaching_time']=reaching_time_0
flights_mum_cheap['destination_city']=city_des_0
flights_mum_cheap['journey_time']=journey_t_0
flights_mum_cheap['stop']=no_of_stops_0
flights_mum_cheap['ticket fare']=fare_0
flights_mum_cheap
# Out:
#           airline          departure_city departure_time reaching_time  \
# 0         Vistara  DEL Indira Gandhi Intl          06:00         08:00
# 1   AirAsia India  DEL Indira Gandhi Intl          13:00         14:50
# 2       Air India  DEL Indira Gandhi Intl          07:00         09:05
# 3       Air India  DEL Indira Gandhi Intl          20:00         22:10
# 4       Air India  DEL Indira Gandhi Intl          08:00         10:10
# 5         Vistara  DEL Indira Gandhi Intl          06:00         08:00
# 6         Vistara  DEL Indira Gandhi Intl          09:30         11:35
# 7         Vistara  DEL Indira Gandhi Intl          19:50         22:00
# 8         Vistara  DEL Indira Gandhi Intl          20:40         22:50
# 9       Air India  DEL Indira Gandhi Intl          09:00         11:15
# 10        GoFirst  DEL Indira Gandhi Intl          19:50         22:00
# 11        GoFirst  DEL Indira Gandhi Intl          07:00         09:10
# ...

# %%
#Specify Search URL #mumbai 
url='https://www.kayak.co.in/flights/DEL-BOM/2022-04-19?sort=duration_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines_0=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
try:
    for i in airlines_0:
        airline_0.append(i.text)
except:
    airline_0.append(nan)
print('Length of airlines:',len(airline_0))

#departure time
departure_0 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
try:
    for dept in departure_0:
        departure_time_0.append(dept.text)
except:
    departure_time_0.append(nan)
print('Length of departure time:',len(departure_time_0))

#departure city
city_from_0 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
try:
    for i in city_from_0:
        departure_city_0.append(i.text)
except:
    city_from_0.append(nan)
print('Length of departure city:',len(departure_city_0))

city_dep_0= departure_city_0[0::2]

#destination city
dest_city_0 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city_0:
    destination_city_0.append(i.text)
print('Length of destination city:',len(destination_city_0))

city_des_0=destination_city_0[1::2]

#Destination arrival time
reach_time_0=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time_0:
    reaching_time_0.append(i.text)
print('Length of reaching time:',len(reaching_time_0))

#journey_time
journey_0 = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey_0:
    journey_time_0.append(i.text)
print('Length of journey time:',len(journey_time_0))

journey_t_0=journey_time_0[2: :3]

#no_of_stops
no_stops_0= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops_0:
    no_of_stops_0.append(i.text)
print('Length of number of stops:',len(no_of_stops_0))

 #Ticket fare
ticket_price_0= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price_0:
    price_0.append(prices.text)
print('Length of price:',len(price_0))
# Out:
# Length of airlines: 55
# Length of departure time: 55
# Length of departure city: 110
# Length of destination city: 110
# Length of reaching time: 55
# Length of journey time: 165
# Length of number of stops: 55
# Length of price: 522

# %%
from re import search
pr_0=[]
for i in price_0: 
      if search("₹", i):
            pr_0.append(i)
            
fare_0=pr_0[0:55]

# %%
flights_mum =pd.DataFrame({})
flights_mum['airline']=airline_0
flights_mum['departure_city']=city_dep_0
flights_mum['departure_time']=departure_time_0
flights_mum['reaching_time']=reaching_time_0
flights_mum['destination_city']=city_des_0
flights_mum['journey_time']=journey_t_0
flights_mum['stop']=no_of_stops_0
flights_mum['ticket fare']=fare_0
flights_mum
# Out:
#           airline          departure_city departure_time reaching_time  \
# 0         Vistara  DEL Indira Gandhi Intl          06:00         08:00
# 1   AirAsia India  DEL Indira Gandhi Intl          13:00         14:50
# 2       Air India  DEL Indira Gandhi Intl          07:00         09:05
# 3       Air India  DEL Indira Gandhi Intl          20:00         22:10
# 4       Air India  DEL Indira Gandhi Intl          08:00         10:10
# 5         Vistara  DEL Indira Gandhi Intl          06:00         08:00
# 6         Vistara  DEL Indira Gandhi Intl          09:30         11:35
# 7         Vistara  DEL Indira Gandhi Intl          19:50         22:00
# 8         Vistara  DEL Indira Gandhi Intl          20:40         22:50
# 9       Air India  DEL Indira Gandhi Intl          09:00         11:15
# 10        GoFirst  DEL Indira Gandhi Intl          19:50         22:00
# 11        GoFirst  DEL Indira Gandhi Intl          07:00         09:10
# ...

# %%
flights_mum.to_csv('airlines_mumbai.csv')

# %%
df2 = pd.read_csv ("airlines_mumbai.csv")
df2
# Out:
#     Unnamed: 0        airline          departure_city departure_time  \
# 0            0        Vistara  DEL Indira Gandhi Intl          06:00
# 1            1  AirAsia India  DEL Indira Gandhi Intl          13:00
# 2            2      Air India  DEL Indira Gandhi Intl          07:00
# 3            3      Air India  DEL Indira Gandhi Intl          20:00
# 4            4      Air India  DEL Indira Gandhi Intl          08:00
# 5            5        Vistara  DEL Indira Gandhi Intl          06:00
# 6            6        Vistara  DEL Indira Gandhi Intl          09:30
# 7            7        Vistara  DEL Indira Gandhi Intl          19:50
# 8            8        Vistara  DEL Indira Gandhi Intl          20:40
# 9            9      Air India  DEL Indira Gandhi Intl          09:00
# 10          10        GoFirst  DEL Indira Gandhi Intl          19:50
# 11          11        GoFirst  DEL Indira Gandhi Intl          07:00
# 12          12        GoFirst  DEL Indira Gandhi Intl          18:20
# ...

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# Activating the chrome browser
driver= webdriver.Chrome(r"E:\chromedriver_win32\chromedriver.exe") 

#Details scrapped
airline_1=[]
departure_time_1=[]
departure_city_1=[]
reaching_time_1=[]
destination_city_1=[]
price_1=[]
journey_time_1=[]
no_of_stops_1=[]

#Specify Search URL #kolatta 
url='https://www.kayak.co.in/flights/DEL-CCU/2022-04-19?sort=bestflight_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines_1=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
for i in airlines_1:
    airline_1.append(i.text)
print('Length of airlines:',len(airline_1))

#departure time
departure_1 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
for dept in departure_1:
        departure_time_1.append(dept.text)
print('Length of departure time:',len(departure_time_1))

#departure city
city_from_1 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in city_from_1:
        departure_city_1.append(i.text)

print('Length of departure city:',len(departure_city_1))

city_dep_1= departure_city_1[0::2]

#destination city
dest_city_1 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city_1:
    destination_city_1.append(i.text)
print('Length of destination city:',len(destination_city_1))

city_des_1=destination_city_1[1::2]

#Destination arrival time
reach_time_1=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time_1:
    reaching_time_1.append(i.text)
print('Length of reaching time:',len(reaching_time_1))

#journey_time
journey_1 = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey_1:
    journey_time_1.append(i.text)
print('Length of journey time:',len(journey_time_1))

journey_t_1=journey_time_1[2: :3]

#no_of_stops
no_stops_1= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops_1:
    no_of_stops_1.append(i.text)
print('Length of number of stops:',len(no_of_stops_1))

 #Ticket fare
ticket_price_1= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price_1:
    price_1.append(prices.text)
print('Length of price:',len(price_1))
# Out:
# Length of airlines: 48
# Length of departure time: 48
# Length of departure city: 96
# Length of destination city: 96
# Length of reaching time: 48
# Length of journey time: 144
# Length of number of stops: 48
# Length of price: 585

# %%
from re import search
pr_1=[]
for i in price_1: 
      if search("₹", i):
            pr_1.append(i)
            
fare_1=pr_1[0:48]

# %%
flights_kol_best =pd.DataFrame({})
flights_kol_best['airline']=airline_1[0:48]
flights_kol_best['departure_city']=city_dep_1[0:48]
flights_kol_best['departure_time']=departure_time_1[0:48]
flights_kol_best['reaching_time']=reaching_time_1[0:48]
flights_kol_best['destination_city']=city_des_1[0:48]
flights_kol_best['journey_time']=journey_t_1[0:48]
flights_kol_best['stop']=no_of_stops_1[0:48]
flights_kol_best['ticket fare']=fare_1
flights_kol_best
# Out:
#           airline          departure_city departure_time reaching_time  \
# 0         GoFirst  DEL Indira Gandhi Intl          05:45         07:50
# 1         Vistara  DEL Indira Gandhi Intl          20:30         22:45
# 2        SpiceJet  DEL Indira Gandhi Intl          07:05         09:05
# 3         Vistara  DEL Indira Gandhi Intl          06:15         08:20
# 4         Vistara  DEL Indira Gandhi Intl          07:30         09:35
# 5        SpiceJet  DEL Indira Gandhi Intl          18:15         20:25
# 6          IndiGo  DEL Indira Gandhi Intl          06:05         07:50
# 7         Vistara  DEL Indira Gandhi Intl          17:30         19:35
# 8         Vistara  DEL Indira Gandhi Intl          15:55         18:05
# 9        SpiceJet  DEL Indira Gandhi Intl          19:30         21:55
# 10         IndiGo  DEL Indira Gandhi Intl          12:25         14:30
# 11         IndiGo  DEL Indira Gandhi Intl          20:00         22:05
# ...

# %%
#Specify Search URL #kolatta 
url='https://www.kayak.co.in/flights/DEL-CCU/2022-04-19?sort=price_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines_1=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
for i in airlines_1:
    airline_1.append(i.text)
print('Length of airlines:',len(airline_1))

#departure time
departure_1 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
for dept in departure_1:
        departure_time_1.append(dept.text)
print('Length of departure time:',len(departure_time_1))

#departure city
city_from_1 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in city_from_1:
        departure_city_1.append(i.text)

print('Length of departure city:',len(departure_city_1))

city_dep_1= departure_city_1[0::2]

#destination city
dest_city_1 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city_1:
    destination_city_1.append(i.text)
print('Length of destination city:',len(destination_city_1))

city_des_1=destination_city_1[1::2]

#Destination arrival time
reach_time_1=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time_1:
    reaching_time_1.append(i.text)
print('Length of reaching time:',len(reaching_time_1))

#journey_time
journey_1 = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey_1:
    journey_time_1.append(i.text)
print('Length of journey time:',len(journey_time_1))

journey_t_1=journey_time_1[2: :3]

#no_of_stops
no_stops_1= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops_1:
    no_of_stops_1.append(i.text)
print('Length of number of stops:',len(no_of_stops_1))

 #Ticket fare
ticket_price_1= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price_1:
    price_1.append(prices.text)
print('Length of price:',len(price_1))
# Out:
# Length of airlines: 93
# Length of departure time: 93
# Length of departure city: 186
# Length of destination city: 186
# Length of reaching time: 93
# Length of journey time: 279
# Length of number of stops: 93
# Length of price: 1143

# %%
from re import search
pr_1=[]
for i in price_1: 
      if search("₹", i):
            pr_1.append(i)
            
fare_1=pr_1[0:93]

# %%
flights_kol_cheap =pd.DataFrame({})
flights_kol_cheap['airline']=airline_1[0:93]
flights_kol_cheap['departure_city']=city_dep_1[0:93]
flights_kol_cheap['departure_time']=departure_time_1[0:93]
flights_kol_cheap['reaching_time']=reaching_time_1[0:93]
flights_kol_cheap['destination_city']=city_des_1[0:93]
flights_kol_cheap['journey_time']=journey_t_1[0:93]
flights_kol_cheap['stop']=no_of_stops_1[0:93]
flights_kol_cheap['ticket fare']=fare_1
flights_kol_cheap
# Out:
#      airline          departure_city departure_time reaching_time  \
# 0    GoFirst  DEL Indira Gandhi Intl          05:45         07:50
# 1    Vistara  DEL Indira Gandhi Intl          20:30         22:45
# 2   SpiceJet  DEL Indira Gandhi Intl          07:05         09:05
# 3    Vistara  DEL Indira Gandhi Intl          06:15         08:20
# 4    Vistara  DEL Indira Gandhi Intl          07:30         09:35
# ..       ...                     ...            ...           ...
# 88   GoFirst  DEL Indira Gandhi Intl          21:25         23:40
# 89    IndiGo  DEL Indira Gandhi Intl          06:05         07:50
# 90    IndiGo  DEL Indira Gandhi Intl          23:30         01:35
# 91    IndiGo  DEL Indira Gandhi Intl          12:25         14:30
# 92    IndiGo  DEL Indira Gandhi Intl          20:00         22:05
#
#          destination_city journey_time    stop ticket fare
# 0   CCU Netaji S. Chandra       2h 05m  direct     ₹ 5,262
# ...

# %%
#Specify Search URL #kolatta 
url='https://www.kayak.co.in/flights/DEL-CCU/2022-04-19?sort=duration_a'


#getting the website
driver.get(url)
time.sleep(5)

# %%
#airlines
airlines_1=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
for i in airlines_1:
    airline_1.append(i.text)
print('Length of airlines:',len(airline_1))

#departure time
departure_1 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
for dept in departure_1:
        departure_time_1.append(dept.text)
print('Length of departure time:',len(departure_time_1))

#departure city
city_from_1 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in city_from_1:
        departure_city_1.append(i.text)

print('Length of departure city:',len(departure_city_1))

city_dep_1= departure_city_1[0::2]

#destination city
dest_city_1 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
for i in dest_city_1:
    destination_city_1.append(i.text)
print('Length of destination city:',len(destination_city_1))

city_des_1=destination_city_1[1::2]

#Destination arrival time
reach_time_1=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
for i in reach_time_1:
    reaching_time_1.append(i.text)
print('Length of reaching time:',len(reaching_time_1))

#journey_time
journey_1 = driver.find_elements_by_xpath('//div[@class="top"]')
for i in journey_1:
    journey_time_1.append(i.text)
print('Length of journey time:',len(journey_time_1))

journey_t_1=journey_time_1[2: :3]

#no_of_stops
no_stops_1= driver.find_elements_by_xpath('//span[@class="stops-text"]')
for i in no_stops_1:
    no_of_stops_1.append(i.text)
print('Length of number of stops:',len(no_of_stops_1))

 #Ticket fare
ticket_price_1= driver.find_elements_by_xpath('//span[@class="price-text"]')
for prices in ticket_price_1:
    price_1.append(prices.text)
print('Length of price:',len(price_1))
# Out:
# Length of airlines: 153
# Length of departure time: 153
# Length of departure city: 295
# Length of destination city: 276
# Length of reaching time: 138
# Length of journey time: 414
# Length of number of stops: 138
# Length of price: 1737

# %%
from re import search
pr_1=[]
for i in price_1: 
      if search("₹", i):
            pr_1.append(i)
            
fare_1=pr_1[0:138]

# %%
flights_kol =pd.DataFrame({})
flights_kol['airline']=airline_1[0:138]
flights_kol['departure_city']=city_dep_1[0:138]
flights_kol['departure_time']=departure_time_1[0:138]
flights_kol['reaching_time']=reaching_time_1[0:138]
flights_kol['destination_city']=city_des_1[0:138]
flights_kol['journey_time']=journey_t_1[0:138]
flights_kol['stop']=no_of_stops_1[0:138]
flights_kol['ticket fare']=fare_1
flights_kol
# Out:
#       airline          departure_city departure_time reaching_time  \
# 0     GoFirst  DEL Indira Gandhi Intl          05:45         07:50
# 1     Vistara  DEL Indira Gandhi Intl          20:30         22:45
# 2    SpiceJet  DEL Indira Gandhi Intl          07:05         09:05
# 3     Vistara  DEL Indira Gandhi Intl          06:15         08:20
# 4     Vistara  DEL Indira Gandhi Intl          07:30         09:35
# ..        ...                     ...            ...           ...
# 133    IndiGo   CCU Netaji S. Chandra          17:35         19:40
# 134    IndiGo   CCU Netaji S. Chandra          08:40         10:45
# 135    IndiGo   CCU Netaji S. Chandra          22:10         00:15
# 136    IndiGo   CCU Netaji S. Chandra          15:20         17:25
# 137    IndiGo   CCU Netaji S. Chandra          18:40         20:45
#
#           destination_city journey_time    stop ticket fare
# 0    CCU Netaji S. Chandra       2h 05m  direct     ₹ 5,262
# ...

# %%
flights_kol.to_csv('airlines_kolkatta.csv')

# %%
df3 = pd.read_csv ("airlines_kolkatta.csv")
df3
# Out:
#      Unnamed: 0   airline          departure_city departure_time  \
# 0             0   GoFirst  DEL Indira Gandhi Intl          05:45
# 1             1   Vistara  DEL Indira Gandhi Intl          20:30
# 2             2  SpiceJet  DEL Indira Gandhi Intl          07:05
# 3             3   Vistara  DEL Indira Gandhi Intl          06:15
# 4             4   Vistara  DEL Indira Gandhi Intl          07:30
# ..          ...       ...                     ...            ...
# 133         133    IndiGo   CCU Netaji S. Chandra          17:35
# 134         134    IndiGo   CCU Netaji S. Chandra          08:40
# 135         135    IndiGo   CCU Netaji S. Chandra          22:10
# 136         136    IndiGo   CCU Netaji S. Chandra          15:20
# 137         137    IndiGo   CCU Netaji S. Chandra          18:40
#
#     reaching_time       destination_city journey_time    stop ticket fare
# 0           07:50  CCU Netaji S. Chandra       2h 05m  direct     ₹ 5,262
# ...

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# Activating the chrome browser
driver= webdriver.Chrome(r"E:\chromedriver_win32\chromedriver.exe") 

#Details scrapped
airline_2=[]
departure_time_2=[]
departure_city_2=[]
reaching_time_2=[]
destination_city_2=[]
price_2=[]
journey_time_2=[]
no_of_stops_2=[]

# %%
#Specify Search URL #chennai 
url=['https://www.kayak.co.in/flights/DEL-MAA/2022-04-19?sort=bestflight_a','https://www.kayak.co.in/flights/DEL-MAA/2022-04-19?sort=price_a','https://www.kayak.co.in/flights/DEL-MAA/2022-04-19?sort=duration_a']


#getting the website
for i in url:
    driver.get(i)
    time.sleep(5)
    #airlines
    airlines_2=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
    for i in airlines_2:
        airline_2.append(i.text)
    print('Length of airlines:',len(airline_2))
    
    #departure time
    departure_2 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
    for dept in departure_2:
        departure_time_2.append(dept.text)
    print('Length of departure time:',len(departure_time_2))
    
    #departure city
    city_from_2 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
    for i in city_from_2:
        departure_city_2.append(i.text)

    print('Length of departure city:',len(departure_city_2))
    
    city_dep_2= departure_city_2[0::2]

#destination city
    dest_city_2 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
    for i in dest_city_2:
        destination_city_2.append(i.text)
    print('Length of destination city:',len(destination_city_2))

    city_des_2=destination_city_2[1::2]

#Destination arrival time
    reach_time_2=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
    for i in reach_time_2:
        reaching_time_2.append(i.text)
    print('Length of reaching time:',len(reaching_time_2))

#journey_time
    journey_2 = driver.find_elements_by_xpath('//div[@class="top"]')
    for i in journey_2:
        journey_time_2.append(i.text)
    print('Length of journey time:',len(journey_time_2))

    journey_t_2=journey_time_2[2: :3]

#no_of_stops
    no_stops_2= driver.find_elements_by_xpath('//span[@class="stops-text"]')
    for i in no_stops_2:
        no_of_stops_2.append(i.text)
    print('Length of number of stops:',len(no_of_stops_2))
    
     #Ticket fare
    ticket_price_2= driver.find_elements_by_xpath('//span[@class="price-text"]')
    for prices in ticket_price_2:
        price_2.append(prices.text)
    print('Length of price:',len(price_2))
# Out:
# Length of airlines: 295
# Length of departure time: 252
# Length of departure city: 462
# Length of destination city: 460
# Length of reaching time: 216
# Length of journey time: 648
# Length of number of stops: 216
# Length of price: 2600
# Length of airlines: 310
# Length of departure time: 267
# Length of departure city: 492
# Length of destination city: 490
# Length of reaching time: 231
# Length of journey time: 693
# Length of number of stops: 231
# Length of price: 2786
# Length of airlines: 325
# Length of departure time: 282
# Length of departure city: 522
# Length of destination city: 520
# Length of reaching time: 246
# Length of journey time: 738
# Length of number of stops: 246
# Length of price: 2971

# %%
print('airline',len(airline_2))
print('city dep',len(city_dep_2))
print('dep time',len(departure_time_2))
print('arr time',len(reaching_time_2))
print('city des',len(city_des_2))
print('journey',len(journey_t_2))
print('stop',len(no_of_stops_2))
print('price', len(price_2))
# Out:
# airline 325
# city dep 261
# dep time 282
# arr time 246
# city des 260
# journey 246
# stop 246
# price 2971

# %%
from re import search
pr_2=[]
for i in price_2: 
      if search("₹", i):
            pr_2.append(i)
            
fare_2=pr_2[0:246]

# %%
flights_che =pd.DataFrame({})
flights_che['airline']=airline_2[0:246]
flights_che['departure_city']=city_dep_2[0:246]
flights_che['departure_time']=departure_time_2[0:246]
flights_che['reaching_time']=reaching_time_2[0:246]
flights_che['destination_city']=city_des_2[0:246]
flights_che['journey_time']=journey_t_2[0:246]
flights_che['stop']=no_of_stops_2[0:246]
flights_che['ticket fare']=fare_2
flights_che
# Out:
#        airline          departure_city departure_time reaching_time  \
# 0      Vistara  DEL Indira Gandhi Intl          07:10         09:55
# 1      Vistara  DEL Indira Gandhi Intl          07:10         09:55
# 2     SpiceJet  DEL Indira Gandhi Intl          18:25         21:10
# 3      Vistara  DEL Indira Gandhi Intl          19:55         22:45
# 4      Vistara  DEL Indira Gandhi Intl          13:30         16:20
# ..         ...                     ...            ...           ...
# 241     IndiGo  DEL Indira Gandhi Intl          07:10         15:50
# 242     IndiGo  DEL Indira Gandhi Intl          20:30         18:35
# 243  Air India  DEL Indira Gandhi Intl          08:30         12:40
# 244  Air India  DEL Indira Gandhi Intl          12:55         12:45
# 245     IndiGo  DEL Indira Gandhi Intl          15:40         23:35
#
#     destination_city journey_time    stop ticket fare
# 0        MAA Chennai       2h 45m  direct     ₹ 4,976
# ...

# %%
flights_che.to_csv('airlines_chennai.csv')

# %%
df4 = pd.read_csv ("airlines_chennai.csv")
df4
# Out:
#      Unnamed: 0    airline          departure_city departure_time  \
# 0             0    Vistara  DEL Indira Gandhi Intl          07:10
# 1             1    Vistara  DEL Indira Gandhi Intl          07:10
# 2             2   SpiceJet  DEL Indira Gandhi Intl          18:25
# 3             3    Vistara  DEL Indira Gandhi Intl          19:55
# 4             4    Vistara  DEL Indira Gandhi Intl          13:30
# ..          ...        ...                     ...            ...
# 241         241     IndiGo  DEL Indira Gandhi Intl          07:10
# 242         242     IndiGo  DEL Indira Gandhi Intl          20:30
# 243         243  Air India  DEL Indira Gandhi Intl          08:30
# 244         244  Air India  DEL Indira Gandhi Intl          12:55
# 245         245     IndiGo  DEL Indira Gandhi Intl          15:40
#
#     reaching_time destination_city journey_time    stop ticket fare
# 0           09:55      MAA Chennai       2h 45m  direct     ₹ 4,976
# ...

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# Activating the chrome browser
driver= webdriver.Chrome(r"E:\chromedriver_win32\chromedriver.exe") 

#Details scrapped
airline_3=[]
departure_time_3=[]
departure_city_3=[]
reaching_time_3=[]
destination_city_3=[]
price_3=[]
journey_time_3=[]
no_of_stops_3=[]

# %%
#Specify Search URL #chennai 
url=['https://www.kayak.co.in/flights/DEL-BLR/2022-04-19?sort=bestflight_a',
     'https://www.kayak.co.in/flights/DEL-BLR/2022-04-19?sort=price_a',
     'https://www.kayak.co.in/flights/DEL-BLR/2022-04-19?sort=duration_a',
    'https://www.kayak.co.in/flights/DEL-GOI/2022-04-19?sort=bestflight_a',
    'https://www.kayak.co.in/flights/DEL-GOI/2022-04-19?sort=price_a',
    'https://www.kayak.co.in/flights/DEL-GOI/2022-04-19?sort=duration_a',
    'https://www.kayak.co.in/flights/DEL-TRV/2022-04-19?sort=bestflight_a',
    'https://www.kayak.co.in/flights/DEL-TRV/2022-04-19?sort=price_a',
    'https://www.kayak.co.in/flights/DEL-TRV/2022-04-19?sort=duration_a',
    'https://www.kayak.co.in/flights/DEL-AMD/2022-04-19?sort=bestflight_a',
    'https://www.kayak.co.in/flights/DEL-AMD/2022-04-19?sort=price_a',
    'https://www.kayak.co.in/flights/DEL-AMD/2022-04-19?sort=duration_a']


#getting the website
for i in url:
    driver.get(i)
    time.sleep(5)
    #airlines
    airlines_3=driver.find_elements_by_xpath('//span[@class="codeshares-airline-names"]')
    for i in airlines_3:
        airline_3.append(i.text)
    print('Length of airlines:',len(airline_3))
    
    #departure time
    departure_3 = driver.find_elements_by_xpath('//span[@class="depart-time base-time"]')
    for dept in departure_3:
        departure_time_3.append(dept.text)
    print('Length of departure time:',len(departure_time_3))
    
    #departure city
    city_from_3 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
    for i in city_from_3:
        departure_city_3.append(i.text)

    print('Length of departure city:',len(departure_city_3))
    
    city_dep_3= departure_city_3[0::2]

#destination city
    dest_city_3 = driver.find_elements_by_xpath('//span[@class="airport-name"]')
    for i in dest_city_3:
        destination_city_3.append(i.text)
    print('Length of destination city:',len(destination_city_3))

    city_des_3=destination_city_3[1::2]

#Destination arrival time
    reach_time_3=driver.find_elements_by_xpath('//span[@class="arrival-time base-time"]')
    for i in reach_time_3:
        reaching_time_3.append(i.text)
    print('Length of reaching time:',len(reaching_time_3))

#journey_time
    journey_3 = driver.find_elements_by_xpath('//div[@class="top"]')
    for i in journey_3:
        journey_time_3.append(i.text)
    print('Length of journey time:',len(journey_time_3))

    journey_t_3=journey_time_3[2: :3]

#no_of_stops
    no_stops_3= driver.find_elements_by_xpath('//span[@class="stops-text"]')
    for i in no_stops_3:
        no_of_stops_3.append(i.text)
    print('Length of number of stops:',len(no_of_stops_3))
    
     #Ticket fare
    ticket_price_3= driver.find_elements_by_xpath('//span[@class="price-text"]')
    for prices in ticket_price_3:
        price_3.append(prices.text)
    print('Length of price:',len(price_3))
# Out:
# Length of airlines: 857
# Length of departure time: 844
# Length of departure city: 1652
# Length of destination city: 1638
# Length of reaching time: 819
# Length of journey time: 2457
# Length of number of stops: 807
# Length of price: 8209
# Length of airlines: 872
# Length of departure time: 859
# Length of departure city: 1682
# Length of destination city: 1668
# Length of reaching time: 834
# Length of journey time: 2502
# Length of number of stops: 822
# Length of price: 8359
# Length of airlines: 887
# Length of departure time: 874
# Length of departure city: 1712
# Length of destination city: 1698
# Length of reaching time: 849
# Length of journey time: 2547
# Length of number of stops: 837
# Length of price: 8515
# Length of airlines: 903
# Length of departure time: 890
# Length of departure city: 1744
# Length of destination city: 1730
# Length of reaching time: 865
# Length of journey time: 2595
# Length of number of stops: 853
# Length of price: 8655
# ...

# %%
print('airline',len(airline_3))
print('city dep',len(city_dep_3))
print('dep time',len(departure_time_3))
print('arr time',len(reaching_time_3))
print('city des',len(city_des_3))
print('journey',len(journey_t_3))
print('stop',len(no_of_stops_3))
print('fare',len(price_3))
# Out:
# airline 1023
# city dep 992
# dep time 1010
# arr time 985
# city des 985
# journey 985
# stop 969
# fare 9890

# %%
from re import search
pr_3=[]
for i in price_3: 
      if search("₹", i):
            pr_3.append(i)
            
fare_3=pr_3[0:969]

# %%
flights_3 =pd.DataFrame({})
flights_3['airline']=airline_3[0:969]
flights_3['departure_city']=city_dep_3[0:969]
flights_3['departure_time']=departure_time_3[0:969]
flights_3['reaching_time']=reaching_time_3[0:969]
flights_3['destination_city']=city_des_3[0:969]
flights_3['journey_time']=journey_t_3[0:969]
flights_3['stop']=no_of_stops_3[0:969]
flights_3['ticket fare']=fare_3
flights_3
# Out:
#                airline          departure_city departure_time reaching_time  \
# 0              Vistara  DEL Indira Gandhi Intl          20:40         23:20
# 1              Vistara  DEL Indira Gandhi Intl          20:40         23:20
# 2        AirAsia India  DEL Indira Gandhi Intl          08:10         10:40
# 3            Air India  DEL Indira Gandhi Intl          09:45         12:30
# 4            Air India  DEL Indira Gandhi Intl          06:10         08:55
# ..                 ...                     ...            ...           ...
# 964            Vistara  DEL Indira Gandhi Intl          14:45         18:55
# 965             IndiGo  DEL Indira Gandhi Intl          06:25         08:05
# 966             IndiGo  DEL Indira Gandhi Intl          19:00         06:25
# 967  Vistara, SpiceJet  DEL Indira Gandhi Intl          18:15         00:10
# 968             IndiGo  DEL Indira Gandhi Intl          06:10         21:15
#
#        destination_city journey_time    stop ticket fare
# ...

# %%
flights_3.to_csv('airlines_3.csv')

# %%
df5 = pd.read_csv ("airlines_3.csv")
df5
# Out:
#      Unnamed: 0            airline          departure_city departure_time  \
# 0             0            Vistara  DEL Indira Gandhi Intl          20:40
# 1             1            Vistara  DEL Indira Gandhi Intl          20:40
# 2             2      AirAsia India  DEL Indira Gandhi Intl          08:10
# 3             3          Air India  DEL Indira Gandhi Intl          09:45
# 4             4          Air India  DEL Indira Gandhi Intl          06:10
# ..          ...                ...                     ...            ...
# 964         964            Vistara  DEL Indira Gandhi Intl          14:45
# 965         965             IndiGo  DEL Indira Gandhi Intl          06:25
# 966         966             IndiGo  DEL Indira Gandhi Intl          19:00
# 967         967  Vistara, SpiceJet  DEL Indira Gandhi Intl          18:15
# 968         968             IndiGo  DEL Indira Gandhi Intl          06:10
#
#     reaching_time    destination_city journey_time    stop ticket fare
# ...

# %%
df5.shape
# Out:
# (969, 9)

# %%
frames = [df1, df2, df3, df4, df5]
result = pd.concat(frames)
display(result)
# Out:
#      Unnamed: 0            airline          departure_city departure_time  \
# 0             0          Air India  DEL Indira Gandhi Intl          09:45
# 1             1          Air India  DEL Indira Gandhi Intl          09:45
# 2             2           SpiceJet  DEL Indira Gandhi Intl          21:55
# 3             3          Air India  DEL Indira Gandhi Intl          07:10
# 4             4            Vistara  DEL Indira Gandhi Intl          17:40
# ..          ...                ...                     ...            ...
# 964         964            Vistara  DEL Indira Gandhi Intl          14:45
# 965         965             IndiGo  DEL Indira Gandhi Intl          06:25
# 966         966             IndiGo  DEL Indira Gandhi Intl          19:00
# 967         967  Vistara, SpiceJet  DEL Indira Gandhi Intl          18:15
# 968         968             IndiGo  DEL Indira Gandhi Intl          06:10
#
#     reaching_time       destination_city journey_time    stop ticket fare
# ...

# %%
result.to_csv(r'C:\Users\Admin\Desktop\flight_result.csv')

# %%
data_flight = pd.read_csv ("C:/Users/Admin/Desktop/flight_result.csv")
data_flight
# Out:
#       Unnamed: 0  Unnamed: 0.1            airline          departure_city  \
# 0              0             0          Air India  DEL Indira Gandhi Intl
# 1              1             1          Air India  DEL Indira Gandhi Intl
# 2              2             2           SpiceJet  DEL Indira Gandhi Intl
# 3              3             3          Air India  DEL Indira Gandhi Intl
# 4              4             4            Vistara  DEL Indira Gandhi Intl
# ...          ...           ...                ...                     ...
# 1497         964           964            Vistara  DEL Indira Gandhi Intl
# 1498         965           965             IndiGo  DEL Indira Gandhi Intl
# 1499         966           966             IndiGo  DEL Indira Gandhi Intl
# 1500         967           967  Vistara, SpiceJet  DEL Indira Gandhi Intl
# 1501         968           968             IndiGo  DEL Indira Gandhi Intl
#
#      departure_time reaching_time       destination_city journey_time    stop  \
# ...
